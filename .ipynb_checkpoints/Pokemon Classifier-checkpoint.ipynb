# %% [markdown]
# ## Data Processing

# %%
import os
from pathlib import Path
from keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
p = Path("./dataset/")
dirs = p.glob('*')

image_data = []
labels = []

image_paths = []

label_dict = {'Pikachu':0, 'Bulbasaur':1, 'Meowth':2}
pokemon_label = {0:'Pikachu', 1:'Bulbasaur', 2:'Meowth'}

for folder_dir in dirs:
    label = str(folder_dir).split('\\')[-1]
    
    count=0
    print(folder_dir)
    
    for img_path in folder_dir.glob('*.jpg'):
        img = image.load_img(img_path, target_size=(40,40))
        img_array = image.img_to_array(img)
        image_data.append(img_array)
        
        labels.append(label_dict[label])
        
        count += 1
    
    print(count)
# Out:
# dataset\Bulbasaur
# 176
# dataset\Meowth
# 70
# dataset\Pikachu
# 199

# %% [markdown]
# ## Visualization

# %%
import numpy as np

# %%
X = np.array(image_data)
Y = np.array(labels)

from sklearn.utils import shuffle
X,Y = shuffle(X,Y,random_state=2)

X = X/255.0

print(X.shape, Y.shape)
# Out:
# (445, 40, 40, 3) (445,)

# %%
def drawImage(img, label):
    plt.title(pokemon_label[label])
    plt.axis('off')
    plt.style.use('seaborn')
    plt.imshow(img)
    plt.show()

# %%
for i in range(1,20):
    drawImage(X[i], Y[i])

# %% [markdown]
# ## Create Training and Testing Set

# %%
split = int(X.shape[0] * .8)

X_ = np.array(X)
Y_ = np.array(Y)

#Training Set
X = X_[:split,:]
Y = Y_[:split]

#Testing Set
XTest = X_[split:,:]
YTest = Y_[split:]

print(X.shape, Y.shape)
print(XTest.shape, YTest.shape)
# Out:
# (356, 40, 40, 3) (356,)
# (89, 40, 40, 3) (89,)

# %% [markdown]
# ## Building the Neural Network

# %%
def softmax(a):
    e_pa = np.exp(a)
    ans = e_pa/np.sum(e_pa, axis=1, keepdims=True)
    return ans

# %%
class NeuralNetwork:
    
    def __init__(self, input_size, layers, output_size):
        np.random.seed(0)
        
        model = {}
        
        #First Layer
        model['W1'] = np.random.randn(input_size, layers[0])
        model['b1'] = np.zeros((1, layers[0]))
        
        #Second Layer
        model['W2'] = np.random.randn(layers[0], layers[1])
        model['b2'] = np.zeros((1, layers[1]))
        
        #Third/Output Layer
        model['W3'] = np.random.randn(layers[1], output_size)
        model['b3'] = np.zeros((1, output_size))
        
        self.model = model
    
    def forward(self, x):
        
        W1,W2,W3 = self.model['W1'], self.model['W2'], self.model['W3']
        b1,b2,b3 = self.model['b1'], self.model['b2'], self.model['b3']
        
        z1 = np.dot(x, W1) + b1
        a1 = np.tanh(z1)
        
        z2 = np.dot(a1, W2) + b2
        a2 = np.tanh(z2)
        
        z3 = np.dot(a2, W3) + b3
        y_ = softmax(z3)
        
        self.activation_outputs = (a1,a2,y_)
        return y_
        
    def backward(self, x, y, learning_rate=0.001):
        
        W1,W2,W3 = self.model['W1'], self.model['W2'], self.model['W3']
        b1,b2,b3 = self.model['b1'], self.model['b2'], self.model['b3']
        a1,a2,y_ = self.activation_outputs
        m = x.shape[0]
        
        delta3 = y_ - y
        dw3 = np.dot(a2.T, delta3)
        db3 = np.sum(delta3, axis=0)
        
        delta2 = (1-np.square(a2))*np.dot(delta3, W3.T)
        dw2 = np.dot(a1.T, delta2)
        db2 = np.sum(delta2, axis=0)
        
        delta1 = (1-np.square(a1))*np.dot(delta2, W2.T)
        dw1 = np.dot(X.T, delta1)
        db1 = np.sum(delta1, axis=0)
        
        #Update the model parameters using Gradient Descent
        self.model['W1'] -= learning_rate*dw1
        self.model['b1'] -= learning_rate*db1
        
        self.model['W2'] -= learning_rate*dw2
        self.model['b2'] -= learning_rate*db2
        
        self.model['W3'] -= learning_rate*dw3
        self.model['b3'] -= learning_rate*db3
        
    def predict(self,x):
        y_out = self.forward(x)
        return np.argmax(y_out, axis=1)
    
    def summary(self):
        
        W1,W2,W3 = self.model['W1'], self.model['W2'], self.model['W3']
        a1,a2,y_ = self.activation_outputs
        
        print('W1', W1.shape)
        print('A1', a1.shape)
        
        print('W2', W2.shape)
        print('A2', a2.shape)
        
        print('W3', W3.shape)
        print('Y_', y_.shape)

# %%
def loss(y_oht, p):
    
    l = -np.mean(y_oht*np.log(p))
    return l

def one_hot(y, depth):
    
    m = y.shape[0]
    y_oht = np.zeros((m, depth))
    y_oht[np.arange(m), y] = 1
    return y_oht

# %%
def train(X, Y, model, epochs, learning_rate, logs=True):
    
    training_loss = []
    
    classes = 3
    Y_OHT = one_hot(Y, classes)
    
    for ix in range(epochs):
        
        Y_ = model.forward(X)
        l = loss(Y_OHT, Y_)
        training_loss.append(l)
        model.backward(X, Y_OHT, learning_rate)
        
        if(logs):
            print('Epoch %d Loss %.4f' %(ix,l))
    
    return training_loss

# %%
model = NeuralNetwork(input_size=4800, layers=[100,50], output_size=3)

# %%
X = X.reshape(X.shape[0],-1)
print(X.shape)

XTest = XTest.reshape(XTest.shape[0], -1)
print(XTest.shape)
# Out:
# (356, 4800)
# (89, 4800)

# %%
l = train(X,Y,model,500,0.0002)
# Out:
# Epoch 0 Loss 3.1889
# Epoch 1 Loss 2.4373
# Epoch 2 Loss 1.7468
# Epoch 3 Loss 1.4452
# Epoch 4 Loss 1.2624
# Epoch 5 Loss 1.1441
# Epoch 6 Loss 1.1098
# Epoch 7 Loss 0.9812
# Epoch 8 Loss 0.9642
# Epoch 9 Loss 0.8528
# Epoch 10 Loss 0.8033
# Epoch 11 Loss 0.7348
# Epoch 12 Loss 0.7104
# Epoch 13 Loss 0.7228
# Epoch 14 Loss 0.6546
# Epoch 15 Loss 0.6419
# Epoch 16 Loss 0.5685
# Epoch 17 Loss 0.5365
# Epoch 18 Loss 0.5549
# Epoch 19 Loss 0.5112
# Epoch 20 Loss 0.4873
# Epoch 21 Loss 0.4233
# Epoch 22 Loss 0.4898
# Epoch 23 Loss 0.4524
# Epoch 24 Loss 0.4140
# Epoch 25 Loss 0.3954
# Epoch 26 Loss 0.4912
# Epoch 27 Loss 0.4244
# Epoch 28 Loss 0.4363
# Epoch 29 Loss 0.4278
# Epoch 30 Loss 0.3834
# Epoch 31 Loss 0.3771
# Epoch 32 Loss 0.3755
# Epoch 33 Loss 0.3378
# Epoch 34 Loss 0.3134
# Epoch 35 Loss 0.2971
# Epoch 36 Loss 0.3079
# Epoch 37 Loss 0.2963
# Epoch 38 Loss 0.2657
# Epoch 39 Loss 0.2815
# Epoch 40 Loss 0.3153
# Epoch 41 Loss 0.2577
# Epoch 42 Loss 0.2592
# Epoch 43 Loss 0.2283
# Epoch 44 Loss 0.2127
# Epoch 45 Loss 0.2066
# Epoch 46 Loss 0.2387
# Epoch 47 Loss 0.2301
# Epoch 48 Loss 0.2148
# Epoch 49 Loss 0.2169
# Epoch 50 Loss 0.2624
# Epoch 51 Loss 0.2333
# Epoch 52 Loss 0.2275
# Epoch 53 Loss 0.1929
# Epoch 54 Loss 0.1881
# Epoch 55 Loss 0.1758
# Epoch 56 Loss 0.1752
# Epoch 57 Loss 0.1671
# Epoch 58 Loss 0.1716
# Epoch 59 Loss 0.1607
# Epoch 60 Loss 0.1796
# Epoch 61 Loss 0.1830
# Epoch 62 Loss 0.1768
# Epoch 63 Loss 0.1598
# Epoch 64 Loss 0.1572
# Epoch 65 Loss 0.1743
# Epoch 66 Loss 0.1711
# Epoch 67 Loss 0.1497
# Epoch 68 Loss 0.1380
# Epoch 69 Loss 0.1463
# Epoch 70 Loss 0.1743
# Epoch 71 Loss 0.1811
# Epoch 72 Loss 0.1747
# Epoch 73 Loss 0.1588
# Epoch 74 Loss 0.1538
# Epoch 75 Loss 0.2180
# Epoch 76 Loss 0.1984
# Epoch 77 Loss 0.1599
# Epoch 78 Loss 0.1401
# Epoch 79 Loss 0.1319
# Epoch 80 Loss 0.1242
# Epoch 81 Loss 0.1196
# Epoch 82 Loss 0.1158
# Epoch 83 Loss 0.1172
# Epoch 84 Loss 0.1220
# Epoch 85 Loss 0.1442
# Epoch 86 Loss 0.1099
# Epoch 87 Loss 0.1253
# Epoch 88 Loss 0.1321
# Epoch 89 Loss 0.1274
# Epoch 90 Loss 0.1113
# Epoch 91 Loss 0.1056
# Epoch 92 Loss 0.1055
# Epoch 93 Loss 0.1051
# Epoch 94 Loss 0.1010
# Epoch 95 Loss 0.0995
# Epoch 96 Loss 0.0960
# Epoch 97 Loss 0.1058
# Epoch 98 Loss 0.1038
# Epoch 99 Loss 0.1063
# Epoch 100 Loss 0.1399
# Epoch 101 Loss 0.1114
# Epoch 102 Loss 0.1036
# Epoch 103 Loss 0.1012
# Epoch 104 Loss 0.0974
# Epoch 105 Loss 0.0969
# Epoch 106 Loss 0.0888
# Epoch 107 Loss 0.0940
# Epoch 108 Loss 0.0855
# Epoch 109 Loss 0.0863
# Epoch 110 Loss 0.0909
# Epoch 111 Loss 0.0947
# Epoch 112 Loss 0.0929
# Epoch 113 Loss 0.0872
# Epoch 114 Loss 0.1022
# Epoch 115 Loss 0.1179
# Epoch 116 Loss 0.1111
# Epoch 117 Loss 0.1082
# Epoch 118 Loss 0.0984
# Epoch 119 Loss 0.0947
# Epoch 120 Loss 0.0867
# Epoch 121 Loss 0.0887
# Epoch 122 Loss 0.0937
# Epoch 123 Loss 0.0839
# Epoch 124 Loss 0.0803
# Epoch 125 Loss 0.0786
# Epoch 126 Loss 0.0764
# Epoch 127 Loss 0.0744
# Epoch 128 Loss 0.0738
# Epoch 129 Loss 0.0736
# Epoch 130 Loss 0.0751
# Epoch 131 Loss 0.0727
# Epoch 132 Loss 0.0725
# Epoch 133 Loss 0.0753
# Epoch 134 Loss 0.0815
# Epoch 135 Loss 0.0895
# Epoch 136 Loss 0.0796
# Epoch 137 Loss 0.0722
# Epoch 138 Loss 0.0860
# Epoch 139 Loss 0.0891
# Epoch 140 Loss 0.0854
# Epoch 141 Loss 0.0825
# Epoch 142 Loss 0.0805
# Epoch 143 Loss 0.0749
# Epoch 144 Loss 0.0691
# Epoch 145 Loss 0.0673
# Epoch 146 Loss 0.0676
# Epoch 147 Loss 0.0661
# Epoch 148 Loss 0.0659
# Epoch 149 Loss 0.0652
# Epoch 150 Loss 0.0643
# Epoch 151 Loss 0.0652
# Epoch 152 Loss 0.0633
# Epoch 153 Loss 0.0628
# Epoch 154 Loss 0.0630
# Epoch 155 Loss 0.0665
# Epoch 156 Loss 0.0626
# Epoch 157 Loss 0.0617
# Epoch 158 Loss 0.0595
# Epoch 159 Loss 0.0587
# Epoch 160 Loss 0.0579
# Epoch 161 Loss 0.0574
# Epoch 162 Loss 0.0568
# Epoch 163 Loss 0.0563
# Epoch 164 Loss 0.0561
# Epoch 165 Loss 0.0560
# Epoch 166 Loss 0.0579
# Epoch 167 Loss 0.0554
# Epoch 168 Loss 0.0538
# Epoch 169 Loss 0.0534
# Epoch 170 Loss 0.0530
# Epoch 171 Loss 0.0535
# Epoch 172 Loss 0.0521
# Epoch 173 Loss 0.0520
# Epoch 174 Loss 0.0515
# Epoch 175 Loss 0.0523
# Epoch 176 Loss 0.0504
# Epoch 177 Loss 0.0501
# Epoch 178 Loss 0.0498
# Epoch 179 Loss 0.0495
# Epoch 180 Loss 0.0493
# Epoch 181 Loss 0.0492
# Epoch 182 Loss 0.0488
# Epoch 183 Loss 0.0490
# Epoch 184 Loss 0.0485
# Epoch 185 Loss 0.0490
# Epoch 186 Loss 0.0478
# Epoch 187 Loss 0.0477
# Epoch 188 Loss 0.0474
# Epoch 189 Loss 0.0478
# Epoch 190 Loss 0.0469
# Epoch 191 Loss 0.0471
# Epoch 192 Loss 0.0466
# Epoch 193 Loss 0.0469
# Epoch 194 Loss 0.0461
# Epoch 195 Loss 0.0461
# Epoch 196 Loss 0.0458
# Epoch 197 Loss 0.0459
# Epoch 198 Loss 0.0452
# Epoch 199 Loss 0.0452
# Epoch 200 Loss 0.0450
# Epoch 201 Loss 0.0449
# Epoch 202 Loss 0.0445
# Epoch 203 Loss 0.0444
# Epoch 204 Loss 0.0442
# Epoch 205 Loss 0.0441
# Epoch 206 Loss 0.0438
# Epoch 207 Loss 0.0437
# Epoch 208 Loss 0.0435
# Epoch 209 Loss 0.0433
# Epoch 210 Loss 0.0431
# Epoch 211 Loss 0.0429
# Epoch 212 Loss 0.0428
# Epoch 213 Loss 0.0425
# Epoch 214 Loss 0.0424
# Epoch 215 Loss 0.0421
# Epoch 216 Loss 0.0419
# Epoch 217 Loss 0.0416
# Epoch 218 Loss 0.0414
# Epoch 219 Loss 0.0412
# Epoch 220 Loss 0.0411
# Epoch 221 Loss 0.0409
# Epoch 222 Loss 0.0408
# Epoch 223 Loss 0.0405
# Epoch 224 Loss 0.0402
# Epoch 225 Loss 0.0400
# Epoch 226 Loss 0.0399
# Epoch 227 Loss 0.0398
# Epoch 228 Loss 0.0396
# Epoch 229 Loss 0.0395
# Epoch 230 Loss 0.0394
# Epoch 231 Loss 0.0392
# Epoch 232 Loss 0.0391
# Epoch 233 Loss 0.0390
# Epoch 234 Loss 0.0389
# Epoch 235 Loss 0.0387
# Epoch 236 Loss 0.0386
# Epoch 237 Loss 0.0385
# Epoch 238 Loss 0.0384
# Epoch 239 Loss 0.0383
# Epoch 240 Loss 0.0381
# Epoch 241 Loss 0.0380
# Epoch 242 Loss 0.0379
# Epoch 243 Loss 0.0378
# Epoch 244 Loss 0.0377
# Epoch 245 Loss 0.0376
# Epoch 246 Loss 0.0375
# Epoch 247 Loss 0.0373
# Epoch 248 Loss 0.0372
# Epoch 249 Loss 0.0371
# Epoch 250 Loss 0.0370
# Epoch 251 Loss 0.0369
# Epoch 252 Loss 0.0368
# Epoch 253 Loss 0.0367
# Epoch 254 Loss 0.0366
# Epoch 255 Loss 0.0365
# Epoch 256 Loss 0.0364
# Epoch 257 Loss 0.0363
# Epoch 258 Loss 0.0362
# Epoch 259 Loss 0.0361
# Epoch 260 Loss 0.0360
# Epoch 261 Loss 0.0359
# Epoch 262 Loss 0.0358
# Epoch 263 Loss 0.0357
# Epoch 264 Loss 0.0356
# Epoch 265 Loss 0.0355
# Epoch 266 Loss 0.0354
# Epoch 267 Loss 0.0353
# Epoch 268 Loss 0.0352
# Epoch 269 Loss 0.0351
# Epoch 270 Loss 0.0350
# Epoch 271 Loss 0.0349
# Epoch 272 Loss 0.0348
# Epoch 273 Loss 0.0347
# Epoch 274 Loss 0.0346
# Epoch 275 Loss 0.0345
# Epoch 276 Loss 0.0344
# Epoch 277 Loss 0.0343
# Epoch 278 Loss 0.0342
# Epoch 279 Loss 0.0341
# Epoch 280 Loss 0.0340
# Epoch 281 Loss 0.0339
# Epoch 282 Loss 0.0338
# Epoch 283 Loss 0.0337
# Epoch 284 Loss 0.0336
# Epoch 285 Loss 0.0335
# Epoch 286 Loss 0.0334
# Epoch 287 Loss 0.0333
# Epoch 288 Loss 0.0332
# Epoch 289 Loss 0.0331
# Epoch 290 Loss 0.0330
# Epoch 291 Loss 0.0329
# Epoch 292 Loss 0.0328
# Epoch 293 Loss 0.0327
# Epoch 294 Loss 0.0326
# Epoch 295 Loss 0.0325
# Epoch 296 Loss 0.0324
# Epoch 297 Loss 0.0323
# Epoch 298 Loss 0.0322
# Epoch 299 Loss 0.0321
# Epoch 300 Loss 0.0320
# Epoch 301 Loss 0.0320
# Epoch 302 Loss 0.0319
# Epoch 303 Loss 0.0318
# Epoch 304 Loss 0.0317
# Epoch 305 Loss 0.0316
# Epoch 306 Loss 0.0315
# Epoch 307 Loss 0.0314
# Epoch 308 Loss 0.0313
# Epoch 309 Loss 0.0312
# Epoch 310 Loss 0.0312
# Epoch 311 Loss 0.0311
# Epoch 312 Loss 0.0310
# Epoch 313 Loss 0.0309
# Epoch 314 Loss 0.0308
# Epoch 315 Loss 0.0307
# Epoch 316 Loss 0.0306
# Epoch 317 Loss 0.0305
# Epoch 318 Loss 0.0305
# Epoch 319 Loss 0.0304
# Epoch 320 Loss 0.0303
# Epoch 321 Loss 0.0302
# Epoch 322 Loss 0.0301
# Epoch 323 Loss 0.0300
# Epoch 324 Loss 0.0299
# Epoch 325 Loss 0.0298
# Epoch 326 Loss 0.0298
# Epoch 327 Loss 0.0297
# Epoch 328 Loss 0.0296
# Epoch 329 Loss 0.0295
# Epoch 330 Loss 0.0294
# Epoch 331 Loss 0.0293
# Epoch 332 Loss 0.0292
# Epoch 333 Loss 0.0292
# Epoch 334 Loss 0.0291
# Epoch 335 Loss 0.0290
# Epoch 336 Loss 0.0289
# Epoch 337 Loss 0.0288
# Epoch 338 Loss 0.0287
# Epoch 339 Loss 0.0286
# Epoch 340 Loss 0.0286
# Epoch 341 Loss 0.0285
# Epoch 342 Loss 0.0284
# Epoch 343 Loss 0.0283
# Epoch 344 Loss 0.0282
# Epoch 345 Loss 0.0282
# Epoch 346 Loss 0.0281
# Epoch 347 Loss 0.0280
# Epoch 348 Loss 0.0279
# Epoch 349 Loss 0.0278
# Epoch 350 Loss 0.0277
# Epoch 351 Loss 0.0277
# Epoch 352 Loss 0.0276
# Epoch 353 Loss 0.0275
# Epoch 354 Loss 0.0274
# Epoch 355 Loss 0.0274
# Epoch 356 Loss 0.0273
# Epoch 357 Loss 0.0272
# Epoch 358 Loss 0.0271
# Epoch 359 Loss 0.0271
# Epoch 360 Loss 0.0270
# Epoch 361 Loss 0.0269
# Epoch 362 Loss 0.0268
# Epoch 363 Loss 0.0268
# Epoch 364 Loss 0.0267
# Epoch 365 Loss 0.0266
# Epoch 366 Loss 0.0265
# Epoch 367 Loss 0.0265
# Epoch 368 Loss 0.0264
# Epoch 369 Loss 0.0263
# Epoch 370 Loss 0.0263
# Epoch 371 Loss 0.0262
# Epoch 372 Loss 0.0261
# Epoch 373 Loss 0.0261
# Epoch 374 Loss 0.0260
# Epoch 375 Loss 0.0259
# Epoch 376 Loss 0.0259
# Epoch 377 Loss 0.0258
# Epoch 378 Loss 0.0257
# Epoch 379 Loss 0.0257
# Epoch 380 Loss 0.0256
# Epoch 381 Loss 0.0256
# Epoch 382 Loss 0.0255
# Epoch 383 Loss 0.0254
# Epoch 384 Loss 0.0254
# Epoch 385 Loss 0.0253
# Epoch 386 Loss 0.0253
# Epoch 387 Loss 0.0252
# Epoch 388 Loss 0.0251
# Epoch 389 Loss 0.0251
# Epoch 390 Loss 0.0250
# Epoch 391 Loss 0.0250
# Epoch 392 Loss 0.0249
# Epoch 393 Loss 0.0249
# Epoch 394 Loss 0.0248
# Epoch 395 Loss 0.0247
# Epoch 396 Loss 0.0247
# Epoch 397 Loss 0.0246
# Epoch 398 Loss 0.0246
# Epoch 399 Loss 0.0245
# Epoch 400 Loss 0.0245
# Epoch 401 Loss 0.0244
# Epoch 402 Loss 0.0244
# Epoch 403 Loss 0.0243
# Epoch 404 Loss 0.0243
# Epoch 405 Loss 0.0242
# Epoch 406 Loss 0.0242
# Epoch 407 Loss 0.0241
# Epoch 408 Loss 0.0241
# Epoch 409 Loss 0.0240
# Epoch 410 Loss 0.0240
# Epoch 411 Loss 0.0239
# Epoch 412 Loss 0.0239
# Epoch 413 Loss 0.0238
# Epoch 414 Loss 0.0238
# Epoch 415 Loss 0.0237
# Epoch 416 Loss 0.0237
# Epoch 417 Loss 0.0236
# Epoch 418 Loss 0.0236
# Epoch 419 Loss 0.0235
# Epoch 420 Loss 0.0235
# Epoch 421 Loss 0.0234
# Epoch 422 Loss 0.0234
# Epoch 423 Loss 0.0233
# Epoch 424 Loss 0.0233
# Epoch 425 Loss 0.0233
# Epoch 426 Loss 0.0232
# Epoch 427 Loss 0.0232
# Epoch 428 Loss 0.0231
# Epoch 429 Loss 0.0231
# Epoch 430 Loss 0.0230
# Epoch 431 Loss 0.0230
# Epoch 432 Loss 0.0229
# Epoch 433 Loss 0.0229
# Epoch 434 Loss 0.0229
# Epoch 435 Loss 0.0228
# Epoch 436 Loss 0.0228
# Epoch 437 Loss 0.0227
# Epoch 438 Loss 0.0227
# Epoch 439 Loss 0.0226
# Epoch 440 Loss 0.0226
# Epoch 441 Loss 0.0226
# Epoch 442 Loss 0.0225
# Epoch 443 Loss 0.0225
# Epoch 444 Loss 0.0224
# Epoch 445 Loss 0.0224
# Epoch 446 Loss 0.0224
# Epoch 447 Loss 0.0223
# Epoch 448 Loss 0.0223
# Epoch 449 Loss 0.0222
# Epoch 450 Loss 0.0222
# Epoch 451 Loss 0.0221
# Epoch 452 Loss 0.0221
# Epoch 453 Loss 0.0221
# Epoch 454 Loss 0.0220
# Epoch 455 Loss 0.0220
# Epoch 456 Loss 0.0220
# Epoch 457 Loss 0.0219
# Epoch 458 Loss 0.0219
# Epoch 459 Loss 0.0218
# Epoch 460 Loss 0.0218
# Epoch 461 Loss 0.0218
# Epoch 462 Loss 0.0217
# Epoch 463 Loss 0.0217
# Epoch 464 Loss 0.0216
# Epoch 465 Loss 0.0216
# Epoch 466 Loss 0.0216
# Epoch 467 Loss 0.0215
# Epoch 468 Loss 0.0215
# Epoch 469 Loss 0.0215
# Epoch 470 Loss 0.0214
# Epoch 471 Loss 0.0214
# Epoch 472 Loss 0.0213
# Epoch 473 Loss 0.0213
# Epoch 474 Loss 0.0213
# Epoch 475 Loss 0.0212
# Epoch 476 Loss 0.0212
# Epoch 477 Loss 0.0212
# Epoch 478 Loss 0.0211
# Epoch 479 Loss 0.0211
# Epoch 480 Loss 0.0211
# Epoch 481 Loss 0.0210
# Epoch 482 Loss 0.0210
# Epoch 483 Loss 0.0210
# Epoch 484 Loss 0.0209
# Epoch 485 Loss 0.0209
# Epoch 486 Loss 0.0208
# Epoch 487 Loss 0.0208
# Epoch 488 Loss 0.0208
# Epoch 489 Loss 0.0207
# Epoch 490 Loss 0.0207
# Epoch 491 Loss 0.0207
# Epoch 492 Loss 0.0206
# Epoch 493 Loss 0.0206
# Epoch 494 Loss 0.0206
# Epoch 495 Loss 0.0205
# Epoch 496 Loss 0.0205
# Epoch 497 Loss 0.0205
# Epoch 498 Loss 0.0204
# Epoch 499 Loss 0.0204

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plt.title('Training Loss vs Epochs')
plt.plot(l)
plt.show()

# %%
def getAccuracy(X,Y,model):
    outputs = model.predict(X)
    acc = np.sum(outputs==Y)/Y.shape[0]
    return acc

print('Train Accuracy %.4f' %getAccuracy(X,Y,model))
print('Testing Accuracy %.4f' %getAccuracy(XTest,YTest,model))
# Out:
# Train Accuracy 0.9916
# Testing Accuracy 0.6854

# %%
## Overfitting^^

# %%
from sklearn.metrics import classification_report

# %%
outputs = model.predict(X)
print(classification_report(outputs,Y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       161
#            1       1.00      1.00      1.00       135
#            2       0.97      0.98      0.98        60
#
#    micro avg       0.99      0.99      0.99       356
#    macro avg       0.99      0.99      0.99       356
# weighted avg       0.99      0.99      0.99       356

# %%
test_outputs = model.predict(XTest)
print(classification_report(test_outputs,YTest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.73      0.75        41
#            1       0.66      0.77      0.71        35
#            2       0.44      0.31      0.36        13
#
#    micro avg       0.69      0.69      0.69        89
#    macro avg       0.62      0.60      0.61        89
# weighted avg       0.68      0.69      0.68        89

# %%
from sklearn.metrics import confusion_matrix
from visualize import plot_confusion_matrix

# %%
cnf_matrix = confusion_matrix(outputs,Y)
print(cnf_matrix)
# Out:
# [[159   0   2]
#  [  0 135   0]
#  [  1   0  59]]

# %%
plot_confusion_matrix(cnf_matrix, classes=['Pikachu', 'Bulbasaur', 'Meowth'], title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[159   0   2]
#  [  0 135   0]
#  [  1   0  59]]

# %%
cnf_matrix_test = confusion_matrix(test_outputs,YTest)
print(cnf_matrix_test)
# Out:
# [[30 10  1]
#  [ 4 27  4]
#  [ 5  4  4]]

# %%
plot_confusion_matrix(cnf_matrix_test, classes=['Pikachu', 'Bulbasaur', 'Meowth'], title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[30 10  1]
#  [ 4 27  4]
#  [ 5  4  4]]

# %% [markdown]
# ## Visualize Misclassifications

# %%
for i in range(Y.shape[0]):
    if Y[i] != outputs[i]:
        drawImage(X[i].reshape(40,40,3), Y[i])
        print("Prediction %d %s" %(i, pokemon_label[outputs[i]]))
# Out:
# Prediction 76 Meowth
# Prediction 166 Pikachu
# Prediction 353 Pikachu
